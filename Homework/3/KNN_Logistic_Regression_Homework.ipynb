# %% [markdown]
# # Homework: Logistic Regression and KNN Classification
#
# In this homework, you will work with the `advertising.csv` dataset.
# The goal is to predict whether a user clicked on an advertisement using two classification models:
#
# 1. **Logistic Regression**
# 2. **K-Nearest Neighbors (KNN)**
#
# At the end, you should compare both models and explain which one performed better.
#
# ## Dataset columns
#
# - `Daily Time Spent on Site`: consumer time on site in minutes
# - `Age`: customer age in years
# - `Area Income`: average income of the user's geographical area
# - `Daily Internet Usage`: average minutes per day spent on the internet
# - `Ad Topic Line`: headline of the advertisement
# - `City`: city of the user
# - `Male`: whether the user is male
# - `Country`: country of the user
# - `Timestamp`: time when the user clicked the ad or closed the window
# - `Clicked on Ad`: target column, where `0 = did not click` and `1 = clicked`

# %% [markdown]
# ## 1. Import Libraries
#
# Import the libraries you need for data analysis, visualization, preprocessing, and machine learning.

# %% [markdown]
# ## 2. Load the Dataset
#
# Read the `advertising.csv` file into a DataFrame called `ad_data`.

# %% [markdown]
# ## 3. First Look at the Data
#
# Display the first rows of the dataset.

# %% [markdown]
# ## 4. Dataset Information
#
# Use `.info()` and `.describe()` to understand the columns, data types, missing values, and basic statistics.

# %% [markdown]
# ## 5. Check Missing Values
#
# Check if the dataset contains missing values.
# If missing values exist, decide how to handle them.

# %% [markdown]
# ## 6. Target Column Analysis
#
# Check how many users clicked and did not click on the ad.
#
# Hint: use the `Clicked on Ad` column.

# %% [markdown]
# ## 7. Exploratory Data Analysis
#
# Create a histogram of the `Age` column.

# %% [markdown]
# ## 8. Area Income vs Age
#
# Create a plot that shows the relationship between `Area Income` and `Age`.

# %% [markdown]
# ## 9. Daily Time Spent on Site vs Daily Internet Usage
#
# Create a plot that compares `Daily Time Spent on Site` and `Daily Internet Usage`.
#
# Use the target column as color/hue if possible.

# %% [markdown]
# ## 10. Pairplot
#
# Create a pairplot for the numerical columns and use `Clicked on Ad` as the hue.

# %% [markdown]
# ## 11. Prepare Features and Target
#
# Create:
#
# - `X`: the feature columns
# - `y`: the target column `Clicked on Ad`
#
# Start with numerical columns only.
#
# Suggested numerical features:
#
# - `Daily Time Spent on Site`
# - `Age`
# - `Area Income`
# - `Daily Internet Usage`
# - `Male`

# %% [markdown]
# ## 13. Train-Test Split
#
# Split the data into training and testing sets.

# %% [markdown]
# ## 14. Feature Scaling
#
# Apply `StandardScaler` where needed.
#
# Important idea:
#
# - KNN is distance-based, so scaling is very important.
# - Logistic Regression can also benefit from scaling, especially when features have different ranges.
#
# Fit the scaler only on the training data, then transform both training and testing data.

# %% [markdown]
# # Part A: Logistic Regression

# %% [markdown]
# ## 15. Train Logistic Regression
#
# Create and train a Logistic Regression model.

# %% [markdown]
# ## 16. Logistic Regression Predictions
#
# Use the trained Logistic Regression model to predict the test data.

# %% [markdown]
# ## 17. Evaluate Logistic Regression
#
# Evaluate the Logistic Regression model using:
#
# - Accuracy score
# - Confusion matrix
# - Classification report

# %% [markdown]
# # Part B: KNN Classification

# %% [markdown]
# ## 18. Train a KNN Model
#
# Create and train a KNN model.
#
# Start with `k = 5`.

# %% [markdown]
# ## 19. KNN Predictions
#
# Use the trained KNN model to predict the test data.

# %% [markdown]
# ## 20. Evaluate KNN
#
# Evaluate the KNN model using:
#
# - Accuracy score
# - Confusion matrix
# - Classification report

# %% [markdown]
# ## 21. Try Different K Values
#
# Try different values of `k`, for example from 1 to 30.
#
# For each value, calculate the test accuracy.

# %% [markdown]
# ## 22. Plot KNN Performance
#
# Create a line plot that shows how accuracy changes for different values of `k`.
#
# Then choose the best `k`.

# %% [markdown]
# # Part C: Compare Both Models

# %% [markdown]
# ## 23. Final Model Comparison
#
# Create a small comparison table with the results of:
#
# - Logistic Regression accuracy
# - Best KNN accuracy
# - Best value of `k`
#
# Then answer:
#
# 1. Which model performed better?
# 2. Was scaling important for KNN?
# 3. Which model is easier to explain?
# 4. Which model would you choose for this dataset and why?

# %% [markdown]
# ## 24. Short Written Conclusion
#
# Write a short conclusion in markdown.
#
# Mention:
#
# - Which features seemed useful
# - Which model performed better
# - Whether scaling helped
# - Any limitation of your work

# %% [markdown]
# # Bonus: Cross Validation
#
# Use cross-validation to test Logistic Regression and KNN more reliably.
#
# Suggested tasks:
#
# 1. Use `cross_val_score`.
# 2. Try 5-fold cross-validation.
# 3. Compare the average cross-validation score of Logistic Regression and KNN.
#
# Keep this as a bonus question. Do not worry if your first result is not perfect.

# %% [markdown]
# ## Great Job!
#
# You completed a classification homework using Logistic Regression and KNN.
