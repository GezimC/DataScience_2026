# %% [markdown]
# ### You are given a hr_data, start by importing csv, and answer following questions

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('hr_data.csv')
df.head()

# %% [markdown]
# **7:** Filter and show all employees from the Finance department older than 30 years, and sort by age, descending

# %% [markdown]
# **8:**
# - Find how many values are missing in bonus column
# - Replace with zero missing values in bonus column
# - After replacing bonus values, drop all rows that conatins null values

# %% [markdown]
# **9:** Apply a function to categorize employee based on YearsAtCompany
# <br>'Junior' (<2), 'Mid' (3-5), 'Senior' (>5).
# <br> In which category falls most of the employees

# %% [markdown]
# **10:** Using apply function
# - extract just number part from EmpID, example: EMP1001, extract 1001
# - save to a newcolumn named 'EmployeeId'
# - make that column index column

# %% [markdown]
# **11:**
# - Find average Salary by PerformanceScore
# - Find average Salary by YearsAtCompany
# - Is there any correlation between them

# %% [markdown]
# **12:** Find employees who: (Identify Potential Promotions)
# - Have a `PerformanceScore` of `"Excellent"`
# - Have `YearsAtCompany` > 5
# - Earn less than the **average salary of their department**
#
# Return a filtered DataFrame with columns: `EmpID`, `Name`, `Department`, `Salary`, `YearsAtCompany`, `PerformanceScore`.

# %%
# approach using transform('mean') instead of mean()

# %% [markdown]
# **13:** Create a new column `ScoreValue` that encodes `PerformanceScore` using the following logic:
# - "Excellent" → 4
# - "Good" → 3
# - "Average" → 2
# - "Poor" → 1
#
# Use a **custom function with `apply()`** (not `.map()`), and then compute the **average `ScoreValue` per Department**.

# %% [markdown]
# <b>2. </b> You were given a healthexp dataset ready from seaborn
# <br> a) Show the distribution of Life_Expectancy for different Country groups using boxplot.
# <br> b) Plot a scatter plot of Spending_USD vs Life_Expectancy, color by Country.
# <br> c) Plot a heatmap of average Life_Expectancy per Country and Year. (pivot, index=Country...)
# <br> d) For every plot, try to explain(read) the results (is there a visible trend, any outlier)

# %%
import seaborn as sns
healthexp = sns.load_dataset('healthexp')

# %% [markdown]
# <b>3. </b> You were given a dataset from yfinance
# <br> a) Find the difference of "Open" and "Close" (Close - Open) for each crypto // you may need to use for loop or method .xs(key =, level = 1, axis = 1)
# <br> b) Show the maximum difference (from a)) for each crypto, using barplot
# <br> c) Plot lines for Opening price of DOGE and XRP in same figure
# <br> hint: fig.add_trace( go.Scatter( ... ) )

# %%
import yfinance as yf

# %%
tickers = ['BNB-USD', 'DOGE-USD', 'XRP-USD']
cryptos = yf.download(tickers, '2023-01-01', '2025-01-01',  group_by='ticker')
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 5 completed
#
# 5 Failed downloads:
# ['ETH-USD', 'BNB-USD', 'DOGE-USD', 'XRP-USD', 'BTC-USD']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')

# %% [markdown]
# <b>4.</b> We'll work with titanic dataset. KNN model will be used for prediction

# %%
titanic_ml = sns.load_dataset('titanic')

# %% [markdown]
# <b>a)</b>
# - Use correlation matrix to find potential relations beetween numerical features
# - Based on corr(), which feature looks to be the most correlated feature with 'survived'

# %% [markdown]
# <b>b)</b> Data processing
# - Create a heat map for finding which feature has null values
# - Try to fill missing values (using average) or to drop columns (if it has more than 70% null values)
# - Drop not needed columns (duplicate info, or cant be converted to numeric)
# - Convert categorical values to numerical (you may use pd.get_dummies or do it manually)

# %% [markdown]
# c)
# - Create features dataset (X) and target (y)
# - Split data train test
# - Create knn model with k=3 and predict

# %% [markdown]
# d) Show and interpret evaluation metrics for k=3

# %% [markdown]
# <b>e)</b> Find the k-value for which model will do better prediction (plot accuracy by k-values)
