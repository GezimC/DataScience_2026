# %% [markdown]
# # E-Commerce Purchases Homework
#
# Analyze the `EcommercePurchases.xlsx` dataset using Pandas, Seaborn, and Plotly.
#
# ## Rules
#
# - Use Pandas for data cleaning and analysis.
# - Use Seaborn for static visualizations.
# - Use Plotly for interactive visualizations where requested.
# - Add short written answers where the question asks for interpretation.
# - Submit the completed notebook.

# %% [markdown]
# # 0. Setup
#
# Import the required libraries and load the dataset.

# %% [markdown]
# # Part 1 — Data Understanding

# %% [markdown]
# ## Q1. Dataset Overview
#
# Display the first 5 rows, last 5 rows, dataset shape, column names, and data types.

# %% [markdown]
# ## Q2. Column Meaning and Target Variable
#
# Identify the main column that represents customer spending. Then answer:
#
# 1. Which column is the main numerical business metric?
# 2. What does one row represent?

# %% [markdown]
# ## Q3. Missing Values Check
#
# Check missing values in all columns.

# %% [markdown]
# ## Q4. Duplicate Rows Check
#
# Check if the dataset contains duplicate rows.

# %% [markdown]
# ## Q5. Numerical and Categorical Columns
#
# Separate numerical and categorical columns.

# %% [markdown]
# # Part 2 — Data Cleaning and Data Quality

# %% [markdown]
# ## Q6. Clean Column Names
#
# Create a cleaned copy of the dataset where column names are easier to use in code.
#
# Examples:
#
# - `Purchase Price` → `purchase_price`
# - `AM or PM` → `am_or_pm`
# - `Credit Card` → `credit_card`

# %% [markdown]
# ## Q7. Check Data Types After Renaming
#
# Check data types again using the cleaned dataframe.

# %% [markdown]
# ## 7.1. Handle Missing Values
#
# Check the dataset for missing values in all columns.
#
# Then handle the missing values in the following way:
#
# - For the numerical column with missing values, can be used mean or median or better strategy.
# - For the categorical column with missing values, fill the missing values using the most frequent value of that column, or other strategy, grouping by etc.
#
# After handling the missing values, check again if the dataset still contains any missing values.

# %% [markdown]
# ## Q8. Purchase Price Quality Check
#
# Check the minimum purchase price, maximum purchase price, average purchase price, and whether there are any negative purchase prices.

# %% [markdown]
# ## Q9. Create Email Domain Feature
#
# Using the cleaned dataframe, create a new column called `email_domain`.
#
# Example:
#
# `student@gmail.com` → `gmail.com`

# %% [markdown]
# ## Q10. Extract Credit Card Expiration Month and Year
#
# From `cc_exp_date`, create two new columns:
#
# - `cc_exp_month`
# - `cc_exp_year`

# %% [markdown]
# # Part 3 — Categorical Analysis

# %% [markdown]
# ## Q11. Top 10 Job Titles
#
# Find the top 10 most common job titles.

# %% [markdown]
# ## Q12. Top 10 Companies by Number of Purchases
#
# Find the top 10 companies by number of purchases.

# %% [markdown]
# ## Q13. AM vs PM Purchases
#
# Count how many purchases happened in AM and PM.

# %% [markdown]
# ## Q14. Language Distribution
#
# Show the number of purchases by language.

# %% [markdown]
# ## Q15. Credit Card Provider Distribution
#
# Find the most common credit card providers.

# %% [markdown]
# # Part 4 — Numerical Analysis and GroupBy

# %% [markdown]
# ## Q16. Purchase Price Summary Statistics
#
# Calculate the mean, median, standard deviation, minimum, maximum, and quartiles for `purchase_price`.

# %% [markdown]
# ## Q17. Interpret Mean vs Median
#
# Compare the mean and median purchase price. Answer:
#
# 1. Are they close?
# 2. What does that tell us about the distribution?

# %% [markdown]
# ## Q18. Highest and Lowest Purchases
#
# Find the top 10 highest purchase prices and the bottom 10 lowest purchase prices.

# %% [markdown]
# ## Q19. Average Purchase Price by AM/PM
#
# Calculate average purchase price for AM and PM purchases.

# %% [markdown]
# ## Q20. Average Purchase Price by Language
#
# Calculate average purchase price by language and sort descending.

# %% [markdown]
# ## Q21. Average Purchase Price by Credit Card Provider
#
# Find the top 10 credit card providers by average purchase price.

# %% [markdown]
# ## Q22. Email Domain Analysis
#
# Find the top 10 most common email domains.

# %% [markdown]
# ## Q23. Business Insight Question
#
# Based on your analysis so far, answer:
#
# 1. Which customer segment looks most common?
# 2. Which group has higher average purchase price?
# 3. What would you recommend to the business?
#
# Write 3–5 sentences.

# %% [markdown]
# # Part 5 — Seaborn Visualizations

# %% [markdown]
# ## Q24. Distribution of Purchase Price
#
# Create a histogram of `purchase_price`.

# %% [markdown]
# ## Q25. Boxplot of Purchase Price by AM/PM
#
# Create a boxplot comparing purchase price between AM and PM.

# %% [markdown]
# ## Q26. Countplot of AM/PM Purchases
#
# Create a countplot showing how many purchases happened in AM vs PM.

# %% [markdown]
# ## Q27. Countplot of Top 10 Languages
#
# Create a countplot for the top 10 languages only.

# %% [markdown]
# ## Q28. Barplot: Average Purchase Price by Language
#
# Create a Seaborn barplot using the grouped data from Q20.

# %% [markdown]
# ## Q29. Barplot: Top 10 Credit Card Providers by Average Purchase Price
#
# Create a horizontal barplot for the top 10 providers by average purchase price.

# %% [markdown]
# ## Q30. Relationship Between Expiration Year and Purchase Price
#
# Create a scatter plot using `cc_exp_year` on the x-axis and `purchase_price` on the y-axis.

# %% [markdown]
# ## Q31. Heatmap of Numeric Correlations
#
# Create a correlation heatmap for numeric columns.

# %% [markdown]
# ## Q32. Pairplot for Selected Numeric Columns
#
# Create a pairplot using selected numeric columns:
#
# - `cc_security_code`
# - `cc_exp_month`
# - `cc_exp_year`
# - `purchase_price`
#
# Use `am_or_pm` as hue.

# %% [markdown]
# # Part 6 — Plotly Interactive Visualizations

# %% [markdown]
# ## Q33. Plotly Interactive Scatter
#
# Create an interactive scatter plot with:
#
# - x = `cc_exp_year`
# - y = `purchase_price`
# - color = `am_or_pm`
# - hover data = `company`, `job`, `language`, `cc_provider`

# %% [markdown]
# ## Q34. Plotly Interactive Bar Chart
#
# Create an interactive bar chart showing average purchase price by language.

# %% [markdown]
# # Part 7 — Final Business Report

# %% [markdown]
# ## Q35. Final Summary
#
# Write a short final report with:
#
# 1. Dataset size
# 2. Data quality notes
# 3. Most common customer/payment characteristics
# 4. Key spending statistics
# 5. Most important visualization insight
# 6. One business recommendation
#
# Write 6–10 sentences.

# %% [markdown]
# # Part 8 — Additional Questions

# %% [markdown]
# ## Q36. Top Jobs by Average Purchase Price
#
# Find the top 10 jobs by average purchase price, but only include jobs that appear at least 5 times.

# %% [markdown]
# ## Q37. Create Purchase Category
#
# Create a new column called `purchase_category` using these rules:
#
# - Low: purchase price < 25
# - Medium: purchase price from 25 to 75
# - High: purchase price > 75

# %% [markdown]
# ## Q38. Purchase Category Counts
#
# Count how many purchases are in each `purchase_category`.

# %% [markdown]
# ## Q39. Average Purchase Price by Purchase Category
#
# Calculate the average purchase price for each `purchase_category`.

# %% [markdown]
# ## Q40. Purchase Category Visualization
#
# Create a countplot showing the number of purchases in each `purchase_category`.

# %% [markdown]
# ## Q41. Company Spending Analysis
#
# Find the top 10 companies by total purchase price.

# %% [markdown]
# ## Q42. Final Recommendation from Additional Analysis
#
# Based on the additional analysis, write 3–5 sentences explaining what new business insight you found.

# %% [markdown]
# # Homework Checklist
#
# Before submitting, make sure you have:
#
# - Completed all questions
# - Used Pandas for cleaning and analysis
# - Used Seaborn for visualizations
# - Used Plotly for the required interactive charts
# - Added written interpretations where requested
# - Restarted and ran the notebook from top to bottom without errors
