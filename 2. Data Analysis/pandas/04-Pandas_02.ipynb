# %%
import numpy as np
import pandas as pd

# %%
# recap
# creating dataframe
# adding, droping rows, cols
# accessing rows cols
# dtype, index, columns, shape
# conditional selection
# sorting

# %%
# import transaction excel to df
df = pd.read_excel("Transactions.xlsx")

# %%
pd.DataFrame(data =[{'A':1, 'B':2 }, {'A':5, 'C':10}], index= ['a','b'])
# Out:
#    A    B     C
# a  1  2.0   NaN
# b  5  NaN  10.0

# %%
df['Total'] = df['Quantity'] * df['Price']

# %%
df.loc[0:5, ['Customer', 'Product']]
# Out:
#   Customer  Product
# 0    Alice   Laptop
# 1      Bob    Phone
# 2  Charlie   Tablet
# 3    David    Shoes
# 4     Emma  T-Shirt
# 5    Alice    Phone

# %%
df.loc[20] = [21, 'test', 'product_test', 'category_test', 5, 200, 1000]

# %%
df
# Out:
#     TransactionID Customer       Product       Category  Quantity  Price  \
# 0               1    Alice        Laptop    Electronics         1   1000
# 1               2      Bob         Phone    Electronics         2    500
# 2               3  Charlie        Tablet    Electronics         1    300
# 3               4    David         Shoes        Fashion         3     50
# 4               5     Emma       T-Shirt        Fashion         2     20
# 5               6    Alice         Phone    Electronics         1    500
# 6               7      Bob        Tablet    Electronics         2    300
# 7               8  Charlie        Laptop    Electronics         3   1000
# 8               9    David         Shoes        Fashion         1     50
# 9              10     Emma       T-Shirt        Fashion         2     20
# 10             11    Alice        Laptop    Electronics         1   1000
# 11             12      Bob         Shoes        Fashion         2     50
# ...

# %%
df.loc[22] = {'TransactionID':22, 'Customer':'Test3'}

# %%
df
# Out:
#     TransactionID Customer       Product       Category  Quantity   Price  \
# 0               1    Alice        Laptop    Electronics       1.0  1000.0
# 1               2      Bob         Phone    Electronics       2.0   500.0
# 2               3  Charlie        Tablet    Electronics       1.0   300.0
# 3               4    David         Shoes        Fashion       3.0    50.0
# 4               5     Emma       T-Shirt        Fashion       2.0    20.0
# 5               6    Alice         Phone    Electronics       1.0   500.0
# 6               7      Bob        Tablet    Electronics       2.0   300.0
# 7               8  Charlie        Laptop    Electronics       3.0  1000.0
# 8               9    David         Shoes        Fashion       1.0    50.0
# 9              10     Emma       T-Shirt        Fashion       2.0    20.0
# 10             11    Alice        Laptop    Electronics       1.0  1000.0
# 11             12      Bob         Shoes        Fashion       2.0    50.0
# ...

# %%
mask =  df['Category'] =='Electronics'

# %%
df[mask].sort_values('Total', axis=0, ascending=False).head(1)
# Out:
#    TransactionID Customer Product     Category  Quantity   Price   Total
# 7              8  Charlie  Laptop  Electronics       3.0  1000.0  3000.0

# %% [markdown]
# # Missing Data
#
# Let's show a few convenient methods to deal with Missing Data in pandas:
# - df.dropna(), using thresh
# - df.fillna(value = )
# - df.fillna({'col':value} )

# %%
df
# Out:
#     TransactionID Customer       Product       Category  Quantity   Price  \
# 0               1    Alice        Laptop    Electronics       1.0  1000.0
# 1               2      Bob         Phone    Electronics       2.0   500.0
# 2               3  Charlie        Tablet    Electronics       1.0   300.0
# 3               4    David         Shoes        Fashion       3.0    50.0
# 4               5     Emma       T-Shirt        Fashion       2.0    20.0
# 5               6    Alice         Phone    Electronics       1.0   500.0
# 6               7      Bob        Tablet    Electronics       2.0   300.0
# 7               8  Charlie        Laptop    Electronics       3.0  1000.0
# 8               9    David         Shoes        Fashion       1.0    50.0
# 9              10     Emma       T-Shirt        Fashion       2.0    20.0
# 10             11    Alice        Laptop    Electronics       1.0  1000.0
# 11             12      Bob         Shoes        Fashion       2.0    50.0
# ...

# %%
# create np.nan

df.loc[5, 'Price'] = np.nan
#df.loc[5, 'Category'] = np.nan
df.loc[4, 'Price'] = np.nan

# %%
df
# Out:
#     TransactionID Customer       Product       Category  Quantity   Price  \
# 0               1    Alice        Laptop    Electronics       1.0  1000.0
# 1               2      Bob         Phone    Electronics       2.0   500.0
# 2               3  Charlie        Tablet    Electronics       1.0   300.0
# 3               4    David         Shoes        Fashion       3.0    50.0
# 4               5     Emma       T-Shirt        Fashion       2.0     NaN
# 5               6    Alice         Phone            NaN       1.0     NaN
# 6               7      Bob        Tablet    Electronics       2.0   300.0
# 7               8  Charlie        Laptop    Electronics       3.0  1000.0
# 8               9    David         Shoes        Fashion       1.0    50.0
# 9              10     Emma       T-Shirt        Fashion       2.0    20.0
# 10             11    Alice        Laptop    Electronics       1.0  1000.0
# 11             12      Bob         Shoes        Fashion       2.0    50.0
# ...

# %%
np.floor(len(df.columns)*0.9)
# Out:
# np.float64(6.0)

# %%
df.dropna(axis = 0, thresh= np.floor(len(df.columns)*0.9))
# Out:
#     TransactionID Customer       Product       Category  Quantity   Price  \
# 0               1    Alice        Laptop    Electronics       1.0  1000.0
# 1               2      Bob         Phone    Electronics       2.0   500.0
# 2               3  Charlie        Tablet    Electronics       1.0   300.0
# 3               4    David         Shoes        Fashion       3.0    50.0
# 4               5     Emma       T-Shirt        Fashion       2.0     NaN
# 6               7      Bob        Tablet    Electronics       2.0   300.0
# 7               8  Charlie        Laptop    Electronics       3.0  1000.0
# 8               9    David         Shoes        Fashion       1.0    50.0
# 9              10     Emma       T-Shirt        Fashion       2.0    20.0
# 10             11    Alice        Laptop    Electronics       1.0  1000.0
# 11             12      Bob         Shoes        Fashion       2.0    50.0
# 12             13  Charlie       T-Shirt        Fashion       3.0    20.0
# ...

# %%
df
# Out:
#     TransactionID Customer       Product       Category  Quantity   Price  \
# 0               1    Alice        Laptop    Electronics       1.0  1000.0
# 1               2      Bob         Phone    Electronics       2.0   500.0
# 2               3  Charlie        Tablet    Electronics       1.0   300.0
# 3               4    David         Shoes        Fashion       3.0    50.0
# 4               5     Emma       T-Shirt        Fashion       2.0     NaN
# 5               6    Alice         Phone            NaN       1.0     NaN
# 6               7      Bob        Tablet    Electronics       2.0   300.0
# 7               8  Charlie        Laptop    Electronics       3.0  1000.0
# 8               9    David         Shoes        Fashion       1.0    50.0
# 9              10     Emma       T-Shirt        Fashion       2.0    20.0
# 10             11    Alice        Laptop    Electronics       1.0  1000.0
# 11             12      Bob         Shoes        Fashion       2.0    50.0
# ...

# %%
df.fillna(
    {
        'Price':5000,
        'Category': 'Test'
     }
)
# Out:
#     TransactionID Customer       Product       Category  Quantity   Price  \
# 0               1    Alice        Laptop    Electronics       1.0  1000.0
# 1               2      Bob         Phone    Electronics       2.0   500.0
# 2               3  Charlie        Tablet    Electronics       1.0   300.0
# 3               4    David         Shoes        Fashion       3.0    50.0
# 4               5     Emma       T-Shirt        Fashion       2.0  5000.0
# 5               6    Alice         Phone           Test       1.0  5000.0
# 6               7      Bob        Tablet    Electronics       2.0   300.0
# 7               8  Charlie        Laptop    Electronics       3.0  1000.0
# 8               9    David         Shoes        Fashion       1.0    50.0
# 9              10     Emma       T-Shirt        Fashion       2.0    20.0
# 10             11    Alice        Laptop    Electronics       1.0  1000.0
# 11             12      Bob         Shoes        Fashion       2.0    50.0
# ...

# %%
df.drop(22, axis = 0, inplace= True)

# %%
df[df[['Price','Category']].isna()]
# Out:
#     TransactionID Customer Product Category  Quantity  Price  Total
# 0             NaN      NaN     NaN      NaN       NaN    NaN    NaN
# 1             NaN      NaN     NaN      NaN       NaN    NaN    NaN
# 2             NaN      NaN     NaN      NaN       NaN    NaN    NaN
# 3             NaN      NaN     NaN      NaN       NaN    NaN    NaN
# 4             NaN      NaN     NaN      NaN       NaN    NaN    NaN
# 5             NaN      NaN     NaN      NaN       NaN    NaN    NaN
# 6             NaN      NaN     NaN      NaN       NaN    NaN    NaN
# 7             NaN      NaN     NaN      NaN       NaN    NaN    NaN
# 8             NaN      NaN     NaN      NaN       NaN    NaN    NaN
# 9             NaN      NaN     NaN      NaN       NaN    NaN    NaN
# 10            NaN      NaN     NaN      NaN       NaN    NaN    NaN
# 11            NaN      NaN     NaN      NaN       NaN    NaN    NaN
# 12            NaN      NaN     NaN      NaN       NaN    NaN    NaN
# ...

# %%
df.isna().any(axis=1)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# dtype: bool

# %%
df.isna().any(axis=1)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# dtype: bool

# %%
df[ df.isna().any(axis=1)  ]
# Out:
#    TransactionID Customer  Product Category  Quantity  Price  Total
# 4              5     Emma  T-Shirt  Fashion       2.0    NaN   40.0
# 5              6    Alice    Phone      NaN       1.0    NaN  500.0

# %%
category = df[  df['Product'] == 'Phone'  ]['Category']

# %%
cat = category[category.notna()].head(1)[1]

# %%
df.fillna(
    {
        'Category':cat,
        'Price' : [1000,500, 300, 50, 1000 , 500]

    },
    inplace=True
)

# %%
df
# Out:
#     TransactionID Customer       Product       Category  Quantity   Price  \
# 0               1    Alice        Laptop    Electronics       1.0  1000.0
# 1               2      Bob         Phone    Electronics       2.0   500.0
# 2               3  Charlie        Tablet    Electronics       1.0   300.0
# 3               4    David         Shoes        Fashion       3.0    50.0
# 4               5     Emma       T-Shirt        Fashion       2.0     NaN
# 5               6    Alice         Phone    Electronics       1.0     NaN
# 6               7      Bob        Tablet    Electronics       2.0   300.0
# 7               8  Charlie        Laptop    Electronics       3.0  1000.0
# 8               9    David         Shoes        Fashion       1.0    50.0
# 9              10     Emma       T-Shirt        Fashion       2.0    20.0
# 10             11    Alice        Laptop    Electronics       1.0  1000.0
# 11             12      Bob         Shoes        Fashion       2.0    50.0
# ...

# %%
def find_avg_price_for_product(product):
    return  df[df['Product'] ==product]['Price'].mean()

# %%
t_shirt_mean = find_avg_price_for_product('T-Shirt')
phone_mean = find_avg_price_for_product('Phone')

# %%
df.fillna(
    {
        'Price':
    }
)
# Out:
#     TransactionID Customer       Product       Category  Quantity   Price  \
# 0               1    Alice        Laptop    Electronics       1.0  1000.0
# 1               2      Bob         Phone    Electronics       2.0   500.0
# 2               3  Charlie        Tablet    Electronics       1.0   300.0
# 3               4    David         Shoes        Fashion       3.0    50.0
# 4               5     Emma       T-Shirt        Fashion       2.0     NaN
# 5               6    Alice         Phone    Electronics       1.0     NaN
# 6               7      Bob        Tablet    Electronics       2.0   300.0
# 7               8  Charlie        Laptop    Electronics       3.0  1000.0
# 8               9    David         Shoes        Fashion       1.0    50.0
# 9              10     Emma       T-Shirt        Fashion       2.0    20.0
# 10             11    Alice        Laptop    Electronics       1.0  1000.0
# 11             12      Bob         Shoes        Fashion       2.0    50.0
# ...

# %%
df[(df['Price'].isna()) & (df['Product'] == 'T-Shirt')]['Price'].fillna(t_shirt_mean,inplace =True)
# Out:
# C:\Users\keds30662\AppData\Local\Temp\ipykernel_17052\1065518989.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[(df['Price'].isna()) & (df['Product'] == 'T-Shirt')]['Price'].fillna(t_shirt_mean,inplace =True)

# %%
df.loc[  (df['Price'].isna()) & (df['Product'] == 'T-Shirt')  , 'Price'   ] = t_shirt_mean

# %%
df
# Out:
#     TransactionID Customer       Product       Category  Quantity   Price  \
# 0               1    Alice        Laptop    Electronics       1.0  1000.0
# 1               2      Bob         Phone    Electronics       2.0   500.0
# 2               3  Charlie        Tablet    Electronics       1.0   300.0
# 3               4    David         Shoes        Fashion       3.0    50.0
# 4               5     Emma       T-Shirt        Fashion       2.0    20.0
# 5               6    Alice         Phone    Electronics       1.0     NaN
# 6               7      Bob        Tablet    Electronics       2.0   300.0
# 7               8  Charlie        Laptop    Electronics       3.0  1000.0
# 8               9    David         Shoes        Fashion       1.0    50.0
# 9              10     Emma       T-Shirt        Fashion       2.0    20.0
# 10             11    Alice        Laptop    Electronics       1.0  1000.0
# 11             12      Bob         Shoes        Fashion       2.0    50.0
# ...

# %% [markdown]
# # Groupby
#
# The groupby method allows you to group rows of data together and call aggregate functions
# - sum: Adds up all values in a column or group.
# - mean: Computes the average value.
# - median: Finds the middle value.
# - min / max: Returns the smallest or largest value, respectively.
# - count: Counts the number of non-null values.
# - std / var: Calculates the standard deviation or variance to measure data dispersion.
# - first / last: Returns the first or last value in a group.
# - agg: Allows you to apply multiple aggregate functions simultaneously on one or more columns.

# %% [markdown]
# - Basic Grouping with Sum
# - Multiple Aggregation Functions on Different Columns  df.groupby('col').agg({})
# - GroupBy with Transformation    df.groupby('col') ['col'] .transform('sum')
# - Grouping by Multiple Columns

# %%
df
# Out:
#     TransactionID Customer       Product       Category  Quantity   Price  \
# 0               1    Alice        Laptop    Electronics       1.0  1000.0
# 1               2      Bob         Phone    Electronics       2.0   500.0
# 2               3  Charlie        Tablet    Electronics       1.0   300.0
# 3               4    David         Shoes        Fashion       3.0    50.0
# 4               5     Emma       T-Shirt        Fashion       2.0     NaN
# 5               6    Alice         Phone    Electronics       1.0     NaN
# 6               7      Bob        Tablet    Electronics       2.0   300.0
# 7               8  Charlie        Laptop    Electronics       3.0  1000.0
# 8               9    David         Shoes        Fashion       1.0    50.0
# 9              10     Emma       T-Shirt        Fashion       2.0    20.0
# 10             11    Alice        Laptop    Electronics       1.0  1000.0
# 11             12      Bob         Shoes        Fashion       2.0    50.0
# ...

# %%
df.fillna(
    {
        'Price':  df.groupby(by='Product')['Price'].transform('mean')
    },
    inplace = True
)

# %%
df
# Out:
#     TransactionID Customer       Product       Category  Quantity   Price  \
# 0               1    Alice        Laptop    Electronics       1.0  1000.0
# 1               2      Bob         Phone    Electronics       2.0   500.0
# 2               3  Charlie        Tablet    Electronics       1.0   300.0
# 3               4    David         Shoes        Fashion       3.0    50.0
# 4               5     Emma       T-Shirt        Fashion       2.0    20.0
# 5               6    Alice         Phone    Electronics       1.0   500.0
# 6               7      Bob        Tablet    Electronics       2.0   300.0
# 7               8  Charlie        Laptop    Electronics       3.0  1000.0
# 8               9    David         Shoes        Fashion       1.0    50.0
# 9              10     Emma       T-Shirt        Fashion       2.0    20.0
# 10             11    Alice        Laptop    Electronics       1.0  1000.0
# 11             12      Bob         Shoes        Fashion       2.0    50.0
# ...

# %%
df.groupby(by='Product')['Price'].mean()
# Out:
# Product
# Laptop          1000.0
# Phone            500.0
# Shoes             50.0
# T-Shirt           20.0
# Tablet           300.0
# product_test     200.0
# Name: Price, dtype: float64

# %%
df.groupby(by='Product')['Price'].transform('mean')
# Out:
# 0     1000.0
# 1      500.0
# 2      300.0
# 3       50.0
# 4       20.0
# 5      500.0
# 6      300.0
# 7     1000.0
# 8       50.0
# 9       20.0
# 10    1000.0
# 11      50.0
# 12      20.0
# 13     500.0
# 14     300.0
# 15      50.0
# 16      20.0
# 17    1000.0
# 18     500.0
# 19     300.0
# 20     200.0
# Name: Price, dtype: float64

# %%
import pandas as pd

df = pd.read_excel('Transactions.xlsx')

# %%
df.head()
# Out:
#    TransactionID Customer  Product     Category  Quantity  Price
# 0              1    Alice   Laptop  Electronics         1   1000
# 1              2      Bob    Phone  Electronics         2    500
# 2              3  Charlie   Tablet  Electronics         1    300
# 3              4    David    Shoes      Fashion         3     50
# 4              5     Emma  T-Shirt      Fashion         2     20

# %%
# Total Quantity Sold per Category
# Group the data by 'Category' and find the total Quantity sold for each.

df.groupby('Category')['Quantity'].sum()
# Out:
# Category
# Electronics    20
# Fashion        18
# Name: Quantity, dtype: int64

# %%
df.head()
# Out:
#    TransactionID Customer  Product     Category  Quantity  Price
# 0              1    Alice   Laptop  Electronics         1   1000
# 1              2      Bob    Phone  Electronics         2    500
# 2              3  Charlie   Tablet  Electronics         1    300
# 3              4    David    Shoes      Fashion         3     50
# 4              5     Emma  T-Shirt      Fashion         2     20

# %%
# Average Price per Product
# Group the data by 'Product' and calculate the average Price.
df.groupby('Product')['Price'].mean().sort_values(ascending=False)
# Out:
# Product
# Laptop     1000.0
# Phone       500.0
# Tablet      300.0
# Shoes        50.0
# T-Shirt      20.0
# Name: Price, dtype: float64

# %%
#Total  per Customer
# Find who spent the most .
#df['Total'] = df['Price'] * df['Quantity']
df.groupby('Customer')['Total'].sum().sort_values(ascending=False).head(1)
# Out:
# Customer
# Charlie    4360
# Name: Total, dtype: int64

# %%
# Products with Highest Quantity Sold per Category
# For each Category, find the Product with the highest total Quantity sold.

group_by_cat_prod = df.groupby(['Category','Product'])['Quantity'].sum().reset_index()

# %%
group_by_cat_prod.groupby(['Category','Product'])['Quantity'].max()
# Out:
# Category     Product
# Electronics  Laptop     6
#              Phone      7
#              Tablet     7
# Fashion      Shoes      9
#              T-Shirt    9
# Name: Quantity, dtype: int64

# %%
# Number of Transactions per Customer
# Count how many transactions each Customer has made.
df.groupby('Customer')['TransactionID'].count()
# Out:
# Customer
# Alice      4
# Bob        4
# Charlie    4
# David      4
# Emma       4
# Name: TransactionID, dtype: int64

# %%
# Multiple Aggregations per Customer
# For each Customer, calculate the total Quantity, total Revenue, and average Price.
tbl1 = df.groupby('Customer')[['Quantity','Total']].sum()

# %%
tbl2 = df.groupby('Customer')['Price'].mean()

# %%
tbl1['Avg-Price'] = tbl2

# %%
tbl1
# Out:
#           Quantity  Total  Avg-Price
# Customer
# Alice            6   2650      637.5
# Bob              8   1740      217.5
# Charlie          8   4360      580.0
# David            8   2200      275.0
# Emma             8   1280      160.0

# %%
df.groupby('Customer').agg(
    {
        'Quantity' : 'sum',
        'Total': 'sum',
        'Price' : 'mean'
    }
)
# Out:
#           Quantity  Total  Price
# Customer
# Alice            6   2650  637.5
# Bob              8   1740  217.5
# Charlie          8   4360  580.0
# David            8   2200  275.0
# Emma             8   1280  160.0

# %%
tbl1.drop('Avg-Price', axis=1, inplace=True)

# %%
tbl1
# Out:
#           Quantity  Total
# Customer
# Alice            6   2650
# Bob              8   1740
# Charlie          8   4360
# David            8   2200
# Emma             8   1280

# %%
tbl2
# Out:
# Customer
# Alice      637.5
# Bob        217.5
# Charlie    580.0
# David      275.0
# Emma       160.0
# Name: Price, dtype: float64

# %%
pd.concat([tbl1, tbl2], axis=0)
# Out:
#           Quantity   Total  Price
# Customer
# Alice          6.0  2650.0    NaN
# Bob            8.0  1740.0    NaN
# Charlie        8.0  4360.0    NaN
# David          8.0  2200.0    NaN
# Emma           8.0  1280.0    NaN
# Alice          NaN     NaN  637.5
# Bob            NaN     NaN  217.5
# Charlie        NaN     NaN  580.0
# David          NaN     NaN  275.0
# Emma           NaN     NaN  160.0

# %%
# Filter Customers Who Spent More Than 1000
# Display only the customers whose total  is greater than 2200.

# %%
by_customer = df.groupby('Customer')['Total'].sum()

# %%
by_customer[ by_customer>2200   ]
# Out:
# Customer
# Alice      2650
# Charlie    4360
# Name: Total, dtype: int64

# %%
df.loc [ df['Product']=='Shoes'  , 'Quantity'  ]
# Out:
# 3     3
# 8     1
# 11    2
# 15    3
# Name: Quantity, dtype: int64

# %%
df.loc[8, 'Quantity'] = 4

# %%
# Products with Highest Quantity Sold per Category
# For each Category, find the Product with the highest total Quantity sold.


test = df.groupby(['Category','Product'])['Quantity'].sum()

# %%
max_by_cat = test.groupby('Category').transform('max')

# %%
max_by_cat = max_by_cat.reset_index()

# %%
test['max_per_cat'] = test.groupby('Category').transform('max')

# %%
max_by_cat
# Out:
#       Category  Product Quantity
# 0  Electronics   Laptop       11
# 1  Electronics    Phone       11
# 2  Electronics   Tablet       11
# 3      Fashion    Shoes       12
# 4      Fashion  T-Shirt       12

# %%
test = test.reset_index()

# %%
test['max_by_cat'] = max_by_cat['Quantity']

# %%
test
# Out:
#       Category  Product Quantity max_by_cat
# 0  Electronics   Laptop        6         11
# 1  Electronics    Phone        7         11
# 2  Electronics   Tablet       11         11
# 3      Fashion    Shoes       12         12
# 4      Fashion  T-Shirt        9         12

# %%
test[test['Quantity'] == test['max_by_cat']]
# Out:
#       Category Product Quantity max_by_cat
# 2  Electronics  Tablet       11         11
# 3      Fashion   Shoes       12         12

# %% [markdown]
# # Merging, Joining, and Concatenating
#
# There are 3 main ways of combining DataFrames together: Merging, Joining and Concatenating. In this lecture we will discuss these 3 methods with examples.
#
# ____

# %%
# divide transaction excel in two parts and use to demonstrate:

# %% [markdown]
# ## Concatenation
#
# Concatenation basically glues together DataFrames. Keep in mind that dimensions should match along the axis you are concatenating on. You can use **pd.concat** and pass in a list of DataFrames to concatenate together:
# - is used to combine DataFrames vertically (rows) or horizontally (columns).

# %% [markdown]
# ## Merging
#
# The **merge** function allows you to merge DataFrames together using a similar logic as merging SQL Tables together. For example:
# - pd.merge(df1,df2, on = , how = )

# %%
# employees
# salaries

employees = pd.DataFrame(data = [
    {'Id':1, 'Name':'Avni', 'Dep':'HR'},
    {'Id':2, 'Name':'Agron', 'Dep':'IT'},
    {'Id':3, 'Name':'Filan', 'Dep':'Sales'}
])

salaries = pd.DataFrame(data = [
    {'EmpId':1, 'Salary':1000},
    {'EmpId':2, 'Salary':1500},
    {'EmpId':4, 'Salary':2000}
])

# %%
employees
# Out:
#    Id   Name    Dep
# 0   1   Avni     HR
# 1   2  Agron     IT
# 2   3  Filan  Sales

# %%
salaries
# Out:
#    EmpId  Salary
# 0      1    1000
# 1      2    1500
# 2      4    2000

# %%
pd.merge(employees, salaries, how='inner', left_on='Id', right_on='EmpId')
# Out:
#    Id   Name Dep  EmpId  Salary
# 0   1   Avni  HR      1    1000
# 1   2  Agron  IT      2    1500

# %% [markdown]
# ## Joining
# Merges DataFrames on their index instead of columns.
# - df1.join(df2, how = , lsufix = '', rsufix ='')

# %% [markdown]
# # Operations

# %% [markdown]
# ### Info on Unique Values
# - unique()
# - nunique()
# - value_counts()

# %%
df['Customer'].unique()
# Out:
# array(['Alice', 'Bob', 'Charlie', 'David', 'Emma'], dtype=object)

# %%
df['Customer'].nunique()
# Out:
# 5

# %%
df['Product'].value_counts()
# Out:
# Product
# Laptop     4
# Phone      4
# Tablet     4
# Shoes      4
# T-Shirt    4
# Name: count, dtype: int64

# %% [markdown]
# ### Applying Functions
# - customized functions
# - lamda functions
# - sum, len, count

# %%
# flag a customer as potentian buyer
# get highest paid emp using transform

# %%
bycust = df.groupby('Customer')['Total'].sum()

# %%
def flag_customers(total):
    if total>2200:
       return 'High Po'
    return  'Low Po'

# %%
flag_customers(2300)
# Out:
# 'High Po'

# %%
bycust['Flag'] = bycust.apply(flag_customers)

# %%
df['sum_total'] = df.groupby('Customer')['Total'].transform('sum')

# %%
df['flag'] = df['sum_total'].apply(flag_customers)

# %%
df[['Price','Quantity']].apply(lambda x: x)
# Out:
#     Price  Quantity
# 0    1000         1
# 1     500         2
# 2     300         5
# 3      50         3
# 4      20         2
# 5     500         1
# 6     300         2
# 7    1000         3
# 8      50         4
# 9      20         2
# 10   1000         1
# 11     50         2
# 12     20         3
# 13    500         2
# 14    300         1
# 15     50         3
# 16     20         2
# 17   1000         1
# 18    500         2
# 19    300         3

# %%
import pandas as pd
import numpy as np

df = pd.read_excel('Transactions.xlsx')

# %%
df.groupby('Customer')['Product'].unique().reset_index()
# Out:
#   Customer                          Product
# 0    Alice           [Laptop, Phone, Shoes]
# 1      Bob  [Phone, Tablet, Shoes, T-Shirt]
# 2  Charlie        [Tablet, Laptop, T-Shirt]
# 3    David                   [Shoes, Phone]
# 4     Emma                [T-Shirt, Tablet]

# %%
# 1. Unique Product Count per Customer
unique_prod=df.groupby('Customer')['Product'].unique().reset_index()

# %%
unique_prod
# Out:
#   Customer                          Product
# 0    Alice           [Laptop, Phone, Shoes]
# 1      Bob  [Phone, Tablet, Shoes, T-Shirt]
# 2  Charlie        [Tablet, Laptop, T-Shirt]
# 3    David                   [Shoes, Phone]
# 4     Emma                [T-Shirt, Tablet]

# %%
unique_prod['Counts']=unique_prod['Product'].apply(lambda row: len(row['Product']), axis=1)

# %%
unique_prod
# Out:
#   Customer                          Product  Counts
# 0    Alice           [Laptop, Phone, Shoes]       3
# 1      Bob  [Phone, Tablet, Shoes, T-Shirt]       4
# 2  Charlie        [Tablet, Laptop, T-Shirt]       3
# 3    David                   [Shoes, Phone]       2
# 4     Emma                [T-Shirt, Tablet]       2

# %%
# 2. How many transactions have each buyer
df.groupby('Customer')['TransactionID'].count()
# Out:
# Customer
# Alice      4
# Bob        4
# Charlie    4
# David      4
# Emma       4
# Name: TransactionID, dtype: int64

# %%
df.loc[ 18, 'Quantity' ] = 3

# %%
df.loc[df['Customer']=='David']
# Out:
#     TransactionID Customer Product     Category  Quantity  Price
# 3               4    David   Shoes      Fashion         3     50
# 8               9    David   Shoes      Fashion         1     50
# 13             14    David   Phone  Electronics         2    500
# 18             19    David   Phone  Electronics         2    500

# %%
# 3. Top quantity buyer per category

quant_cust=df.groupby('Customer')[['Quantity']].sum()

# %%
quant_cust[quant_cust['Quantity'] == quant_cust['Quantity'].max()]
# Out:
#           Quantity
# Customer
# Charlie         12

# %%
quant_cust
# Out:
#           Quantity
# Customer
# Alice            6
# Bob             10
# Charlie         12
# David            9
# Emma             8

# %%
quant_cust['Quantity'].idxmax()
# Out:
# 'Charlie'

# %%
quantity_per_cat=df.groupby(['Category','Customer'])['Quantity'].sum().reset_index()

# %%
quantity_per_cat['max_per_cat']=quantity_per_cat.groupby('Category')['Quantity'].transform('max')

# %%
quantity_per_cat[quantity_per_cat['Quantity'] == quantity_per_cat['max_per_cat']]
# Out:
#       Category Customer  Quantity  max_per_cat
# 2  Electronics  Charlie         9            9
# 6      Fashion      Bob         6            6

# %%
sorted_quant=df.groupby(['Category','Customer'])[['Quantity']].sum().sort_values(by='Quantity', ascending=False)

# %%
sorted_quant
# Out:
#                       Quantity
# Category    Customer
# Electronics Charlie          9
# Fashion     Bob              6
# Electronics David            5
#             Bob              4
# Fashion     Emma             4
# Electronics Emma             4
# Fashion     David            4
# Electronics Alice            3
# Fashion     Alice            3
#             Charlie          3

# %%
sorted_quant.groupby('Category').first()
# Out:
#              Quantity
# Category
# Electronics         9
# Fashion             6

# %%
# 1. Transaction Value Label

# %%
# 2. Customer Name Rating

# %%
# 3. Missing Price Indicator

df.loc[5, 'Price'] = np.nan

# %%
df['missing_price']=df[['Price','TransactionID']].apply(lambda row : f'Unknown price at {int(row['TransactionID'])}' if pd.isna(row['Price'])  else 'Known price', axis=1)

# %%
df
# Out:
#     TransactionID Customer  Product     Category  Quantity   Price  \
# 0               1    Alice   Laptop  Electronics         1  1000.0
# 1               2      Bob    Phone  Electronics         2   500.0
# 2               3  Charlie   Tablet  Electronics         1   300.0
# 3               4    David    Shoes      Fashion         3    50.0
# 4               5     Emma  T-Shirt      Fashion         2    20.0
# 5               6    Alice    Phone  Electronics         1     NaN
# 6               7      Bob   Tablet  Electronics         2   300.0
# 7               8  Charlie   Laptop  Electronics         3  1000.0
# 8               9    David    Shoes      Fashion         1    50.0
# 9              10     Emma  T-Shirt      Fashion         2    20.0
# 10             11    Alice   Laptop  Electronics         1  1000.0
# 11             12      Bob    Shoes      Fashion         2    50.0
# 12             13  Charlie  T-Shirt      Fashion         3    20.0
# ...

# %%
# 4. Transaction Description
#  Example: "Alice bought 2 Laptops for 1000.0 each"

df.apply(lambda row: f'{row['Customer']} bought {row['Quantity']} {row['Product']} for {row['Price']} each', axis=1)
# Out:
# 0       Alice bought 1 Laptop for 1000.0 each
# 1           Bob bought 2 Phone for 500.0 each
# 2      Charlie bought 1 Tablet for 300.0 each
# 3          David bought 3 Shoes for 50.0 each
# 4         Emma bought 2 T-Shirt for 20.0 each
# 5           Alice bought 1 Phone for nan each
# 6          Bob bought 2 Tablet for 300.0 each
# 7     Charlie bought 3 Laptop for 1000.0 each
# 8          David bought 1 Shoes for 50.0 each
# 9         Emma bought 2 T-Shirt for 20.0 each
# 10      Alice bought 1 Laptop for 1000.0 each
# 11           Bob bought 2 Shoes for 50.0 each
# 12     Charlie bought 3 T-Shirt for 20.0 each
# 13        David bought 2 Phone for 500.0 each
# 14        Emma bought 1 Tablet for 300.0 each
# 15         Alice bought 3 Shoes for 50.0 each
# 16         Bob bought 4 T-Shirt for 20.0 each
# 17    Charlie bought 5 Laptop for 1000.0 each
# 18        David bought 3 Phone for 500.0 each
# 19        Emma bought 3 Tablet for 300.0 each
# dtype: object

# %%
print('t')
# Out:
# t

# %% [markdown]
# # Data Input and Output
#
# This notebook is the reference code for getting input and output, pandas can read a variety of file types using its pd.read_ methods. Let's take a look at the most common data types:
# - read_csv()
# - to_csv()
# - read_excel()
# - to_excel()
# - html
# - api  - import requests
# - sql

# %%
url = 'https://www.w3schools.com/html/html_tables.asp'

# %%
tables  = pd.read_html(url)

# %%
tables[1]
# Out:
#           Tag                                        Description
# 0     <table>                                    Defines a table
# 1        <th>                   Defines a header cell in a table
# 2        <tr>                           Defines a row in a table
# 3        <td>                          Defines a cell in a table
# 4   <caption>                            Defines a table caption
# 5  <colgroup>  Specifies a group of one or more columns in a ...
# 6       <col>  Specifies column properties for each column wi...
# 7     <thead>               Groups the header content in a table
# 8     <tbody>                 Groups the body content in a table
# 9     <tfoot>               Groups the footer content in a table

# %%
import requests

# %%
ulr= 'https://jsonplaceholder.typicode.com/users'

# %%
response = requests.get(ulr)

# %%
data = response.json()

# %%
pd.DataFrame(data = data)
# Out:
#    id                      name          username                      email  \
# 0   1             Leanne Graham              Bret          Sincere@april.biz
# 1   2              Ervin Howell         Antonette          Shanna@melissa.tv
# 2   3          Clementine Bauch          Samantha         Nathan@yesenia.net
# 3   4          Patricia Lebsack          Karianne  Julianne.OConner@kory.org
# 4   5          Chelsey Dietrich            Kamren   Lucio_Hettinger@annie.ca
# 5   6      Mrs. Dennis Schulist  Leopoldo_Corkery    Karley_Dach@jasper.info
# 6   7           Kurtis Weissnat      Elwyn.Skiles     Telly.Hoeger@billy.biz
# 7   8  Nicholas Runolfsdottir V     Maxime_Nienow       Sherwood@rosamond.me
# 8   9           Glenna Reichert          Delphine    Chaim_McDermott@dana.io
# 9  10        Clementina DuBuque    Moriah.Stanton     Rey.Padberg@karina.biz
#
#                                              address                  phone  \
# ...

# %% [markdown]
# ## HTML
#
# You may need to install htmllib5,lxml, and BeautifulSoup4. In your terminal/command prompt run:
#
#     pip install lxml
#     pip install html5lib
#     pip install BeautifulSoup4
#
# Then restart Jupyter Notebook.
#
# Pandas can read table tabs off of html. For example:

# %%
# pyodbc

import pyodbc
conn = pyodbc.connect(
        'DRIVER={SQL Server};'
        'SERVER=.;'
        'DATABASE=LocalDB;')

#skip

# %%
import sqlalchemy as sql

engine = sql.create_engine("mssql+pyodbc://@./LocalDB?driver=SQL+Server")

quuery = 'DROP TABLE dbo.Materials'

materials=pd.read_sql(quuery, engine)
# Out:
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# Cell In[133], line 7
#       3 engine = sql.create_engine("mssql+pyodbc://@./LocalDB?driver=SQL+Server")
#       5 quuery = 'DROP TABLE dbo.Materials'
# ----> 7 materials=pd.read_sql(quuery, engine)
#
# File D:\Data Disk D\Gezimi's folder\Cacttus\2024-2025\Analiza dhe vizuelizimi i te dhenave\Ushtrime\Grupi-2\DataScience\.venv\Lib\site-packages\pandas\io\sql.py:734, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     724     return pandas_sql.read_table(
#     725         sql,
#     726         index_col=index_col,
#    (...)    731         dtype_backend=dtype_backend,
#     732     )
#     733 else:
# --> 734     return pandas_sql.read_query(
#     735         sql,
#     736         index_col=index_col,
#     737         params=params,
# ...

# %%
materials
# Out:
#        Material StorageLoc MaterialDoc PostingDate
# 0      10000003       D009  4900000750  12/31/2023
# 1      10000007       D010  4900001024  12/31/2023
# 2      10000007       D006  4900001023  12/31/2023
# 3      10000011          0  5000000711  03/06/2024
# 4      10000014          0  5000000711  03/06/2024
# ...         ...        ...         ...         ...
# 34343  70000113       D002  4900004498  12/31/2023
# 34344  70000113       D002  4900006776  12/31/2023
# 34345  70000114       D010  4900003953  12/31/2023
# 34346  70000114       D010  4900004501  12/31/2023
# 34347  70000114       D010  4900006779  12/31/2023
#
# [34348 rows x 4 columns]
